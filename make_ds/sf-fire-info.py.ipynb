# %%
import pandas as pd

# %%
ds = pd.read_csv("../ds/sf-fire-counts-train.csv", low_memory=False)
ds.head()
# Out:
#    Unnamed: 0  count
# 0           0     89
# 1           1     75
# 2           2     60
# 3           3     26
# 4           4     33

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73404 entries, 0 to 73403
# Data columns (total 2 columns):
# Unnamed: 0    73404 non-null int64
# count         73404 non-null int64
# dtypes: int64(2)
# memory usage: 1.1 MB

# %%
# %matplotlib inline
# only in a Jupyter notebook
import matplotlib.pyplot as plt
ds.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# %matplotlib inline
# only in a Jupyter notebook
import matplotlib.pyplot as plt

y = ds['count']
x = [i for i in range(0, len(y))]

plt.plot(x, y)
plt.show()

# %%
# %matplotlib inline
# only in a Jupyter notebook
import matplotlib.pyplot as plt

for i in range(0, 10):
    y = ds['count'][i * 200: i * 200 + 168]
    x = [i for i in range(0, len(y))]
    
    plt.plot(x, y)
    plt.show()

# %%
dsa = pd.read_csv("../data_raw/sf-fire.csv", low_memory=False)

# %%
# Out:
# pandas.core.frame.DataFrame
