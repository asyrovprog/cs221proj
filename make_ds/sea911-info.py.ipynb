# %%
import pandas as pd

# %%
seattle911 = pd.read_csv("../ds/sea911-train.csv", low_memory=False)
seattle911.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
seattle911.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2830 entries, 0 to 2829
# Data columns (total 2 columns):
# Unnamed: 0    2830 non-null int64
# count         2830 non-null int64
# dtypes: int64(2)
# memory usage: 44.3 KB

# %%
# %matplotlib inline
# only in a Jupyter notebook
import matplotlib.pyplot as plt
seattle911.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# %matplotlib inline
# only in a Jupyter notebook
import matplotlib.pyplot as plt

y = seattle911['count']
x = [i for i in range(0, len(y))]

plt.plot(x, y)
plt.show()
