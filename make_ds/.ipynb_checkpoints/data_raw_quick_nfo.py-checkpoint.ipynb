# %%
import pandas as pd

# %%
seattle911 = pd.read_csv("../data_raw/seattle-911.csv", low_memory=False)
seattle911.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CAD CDW ID</th>
#       <th>CAD Event Number</th>
#       <th>General Offense Number</th>
#       <th>Event Clearance Code</th>
#       <th>Event Clearance Description</th>
#       <th>Event Clearance SubGroup</th>
#       <th>Event Clearance Group</th>
#       <th>Event Clearance Date</th>
#       <th>Hundred Block Location</th>
#       <th>District/Sector</th>
#       <th>Zone/Beat</th>
#       <th>Census Tract</th>
#       <th>Longitude</th>
#       <th>Latitude</th>
#       <th>Incident Location</th>
#       <th>Initial Type Description</th>
#       <th>Initial Type Subgroup</th>
#       <th>Initial Type Group</th>
# ...

# %%
seattle911.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1442527 entries, 0 to 1442526
# Data columns (total 19 columns):
# CAD CDW ID                     1442527 non-null object
# CAD Event Number               1442523 non-null float64
# General Offense Number         1442523 non-null float64
# Event Clearance Code           1432207 non-null float64
# Event Clearance Description    1432206 non-null object
# Event Clearance SubGroup       1432206 non-null object
# Event Clearance Group          1432206 non-null object
# Event Clearance Date           1432062 non-null object
# Hundred Block Location         1439035 non-null object
# District/Sector                1441366 non-null object
# Zone/Beat                      1442521 non-null object
# Census Tract                   1439735 non-null float64
# Longitude                      1442521 non-null float64
# Latitude                       1442521 non-null float64
# Incident Location              1442521 non-null object
# ...
