# %%
import pandas as pd

# %%
ds = pd.read_csv("../ds/los-angeles-fire-counts-2001-2017.csv", low_memory=False)
ds.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>817</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>605</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>587</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>699</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>701</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6117 entries, 0 to 6116
# Data columns (total 2 columns):
# Unnamed: 0    6117 non-null int64
# count         6117 non-null int64
# dtypes: int64(2)
# memory usage: 95.7 KB

# %%
# %matplotlib inline
# only in a Jupyter notebook
import matplotlib.pyplot as plt
ds.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# %matplotlib inline
# only in a Jupyter notebook
import matplotlib.pyplot as plt

y = ds['count']
x = [i for i in range(0, len(y))]

plt.plot(x, y)
plt.show()
